# %%
import os
import cv2
import shutil
from ultralytics import YOLO

# Rutas
model_path = "runs/detect/train/weights/best.pt"  # Modelo entrenado
input_folder = "C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/"  # Carpeta con imágenes nuevas
output_folder = "C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/"  # Carpeta donde se guardarán las imágenes con detecciones
arco_superior_folder = os.path.join(output_folder, "arco_superior")  # Carpeta para imágenes con arco superior

# Crear carpetas de salida si no existen
os.makedirs(output_folder, exist_ok=True)
os.makedirs(arco_superior_folder, exist_ok=True)

# Cargar el modelo entrenado
model = YOLO(model_path)

# Lista de imágenes en la carpeta
image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

# Procesar cada imagen
for image_name in image_files:
    image_path = os.path.join(input_folder, image_name)
    
    # Realizar inferencia
    results = model(image_path)
    
    # Cargar imagen original
    img = cv2.imread(image_path)
    save_in_arco_superior = False  # Bandera para marcar si contiene "Arco Superior"

    for result in results:
        boxes = result.boxes.xyxy  # Coordenadas de las cajas [x1, y1, x2, y2]
        confidences = result.boxes.conf  # Confianza de cada predicción
        class_ids = result.boxes.cls.int().tolist()  # Clases detectadas
        
        for i, (box, conf, class_id) in enumerate(zip(boxes, confidences, class_ids)):
            x1, y1, x2, y2 = map(int, box)  # Convertir a enteros
            label = "Arco Superior" if class_id == 0 else "Arco Inferior"
            color = (0, 0, 255) if class_id == 0 else (255, 0, 0)  # Rojo para superior, azul para inferior

            # Dibujar rectángulo y texto
            cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
            cv2.putText(img, f"{label} ({conf:.2f})", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            # Si detecta "Arco Superior", marcamos la bandera
            if class_id == 0:
                save_in_arco_superior = True

    # Guardar imagen con las detecciones en la carpeta principal
    output_path = os.path.join(output_folder, image_name)
    cv2.imwrite(output_path, img)
    print(f"✅ Guardado: {output_path}")

    # Si contiene "Arco Superior", copiarla a la carpeta específica
    if save_in_arco_superior:
        shutil.copy(output_path, os.path.join(arco_superior_folder, image_name))
        print(f"📂 Copiada a 'arco_superior': {image_name}")

print("🚀 Detección completada. Las imágenes procesadas están en 'output/', y las de arco superior en 'output/arco_superior/'.")
# Out:
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0001.jpeg: 640x640 (no detections), 132.7ms
# Speed: 7.6ms preprocess, 132.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0001.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0002.jpeg: 640x640 (no detections), 99.0ms
# Speed: 4.1ms preprocess, 99.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0002.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0003.jpeg: 640x640 (no detections), 130.9ms
# Speed: 4.6ms preprocess, 130.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0003.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0004.jpeg: 640x640 (no detections), 94.1ms
# Speed: 3.1ms preprocess, 94.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0004.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0005.jpeg: 640x640 (no detections), 89.6ms
# Speed: 5.6ms preprocess, 89.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0005.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0006.jpeg: 640x640 (no detections), 112.9ms
# Speed: 6.1ms preprocess, 112.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0006.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0007.jpeg: 640x640 (no detections), 102.0ms
# Speed: 5.5ms preprocess, 102.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0007.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0008.jpeg: 640x640 (no detections), 95.3ms
# Speed: 7.2ms preprocess, 95.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0008.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0009.jpeg: 640x640 (no detections), 110.2ms
# Speed: 4.9ms preprocess, 110.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0009.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0010.jpeg: 640x640 (no detections), 105.5ms
# Speed: 10.5ms preprocess, 105.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image
6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0101.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0102.jpeg: 640x640 1 arco_inferior, 100.2ms
# Speed: 6.2ms preprocess, 100.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0102.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0103.jpeg: 640x640 1 arco_inferior, 90.9ms
# Speed: 5.2ms preprocess, 90.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0103.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0104.jpeg: 640x640 1 arco_inferior, 90.3ms
# Speed: 5.8ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0104.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0105.jpeg: 640x640 1 arco_inferior, 95.0ms
# Speed: 7.4ms preprocess, 95.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0105.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0106.jpeg: 640x640 1 arco_inferior, 90.1ms
# Speed: 5.7ms preprocess, 90.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0106.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0107.jpeg: 640x640 1 arco_inferior, 96.2ms
# Speed: 5.8ms preprocess, 96.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0107.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0108.jpeg: 640x640 1 arco_inferior, 97.6ms
# Speed: 6.3ms preprocess, 97.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0108.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0109.jpeg: 640x640 1 arco_inferior, 86.8ms
# Speed: 6.8ms preprocess, 86.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0109.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0110.jpeg: 640x640 1 arco_inferior, 91.7ms
# Speed: 4.6ms preprocess, 91.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0110.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0111.jpeg: 640x640 1 arco_inferior, 83.7ms
# Speed: 5.5ms preprocess, 83.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0111.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0112.jpeg: 640x640 1 arco_inferior, 94.4ms
# Speed: 5.5ms preprocess, 94.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0112.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0113.jpeg: 640x640 1 arco_inferior, 122.2ms
# Speed: 5.1ms preprocess, 122.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0113.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0114.jpeg: 640x640 1 arco_inferior, 84.1ms
# Speed: 7.1ms preprocess, 84.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0114.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0115.jpeg: 640x640 1 arco_superior, 1 arco_inferior, 120.0ms
# Speed: 5.3ms preprocess, 120.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0115.jpeg
# 📂 Copiada a 'arco_superior': image0115.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0116.jpeg: 640x640 1 arco_superior, 1 arco_inferior, 91.3ms
# Speed: 6.0ms preprocess, 91.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0116.jpeg
# 📂 Copiada a 'arco_superior': image0116.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0117.jpeg: 640x640 1 arco_superior, 1 arco_inferior, 104.8ms
# Speed: 10.7ms preprocess, 104.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0117.jpeg
# 📂 Copiada a 'arco_superior': image0117.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0118.jpeg: 640x640 1 arco_superior, 1 arco_inferior, 106.9ms
# Speed: 6.5ms preprocess, 106.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0118.jpeg
# 📂 Copiada a 'arco_superior': image0118.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0119.jpeg: 640x640 1 arco_superior, 110.5ms
# Speed: 5.6ms preprocess, 110.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0119.jpeg
# 📂 Copiada a 'arco_superior': image0119.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0120.jpeg: 640x640 1 arco_superior, 85.6ms
# Speed: 7.8ms preprocess, 85.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0120.jpeg
# 📂 Copiada a 'arco_superior': image0120.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0121.jpeg: 640x640 1 arco_superior, 91.4ms
# Speed: 5.5ms preprocess, 91.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0121.jpeg
# 📂 Copiada a 'arco_superior': image0121.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0122.jpeg: 640x640 1 arco_superior, 97.0ms
# Speed: 5.6ms preprocess, 97.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0122.jpeg
# 📂 Copiada a 'arco_superior': image0122.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0123.jpeg: 640x640 1 arco_superior, 107.2ms
# Speed: 7.8ms preprocess, 107.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0123.jpeg
# 📂 Copiada a 'arco_superior': image0123.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0124.jpeg: 640x640 1 arco_superior, 84.0ms
# Speed: 6.7ms preprocess, 84.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0124.jpeg
# 📂 Copiada a 'arco_superior': image0124.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0125.jpeg: 640x640 1 arco_superior, 123.8ms
# Speed: 7.8ms preprocess, 123.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0125.jpeg
# 📂 Copiada a 'arco_superior': image0125.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0126.jpeg: 640x640 1 arco_superior, 97.2ms
# Speed: 5.0ms preprocess, 97.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0126.jpeg
# 📂 Copiada a 'arco_superior': image0126.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0127.jpeg: 640x640 1 arco_superior, 105.5ms
# Speed: 6.7ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0127.jpeg
# 📂 Copiada a 'arco_superior': image0127.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0128.jpeg: 640x640 1 arco_superior, 88.5ms
# Speed: 6.2ms preprocess, 88.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0128.jpeg
# 📂 Copiada a 'arco_superior': image0128.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0129.jpeg: 640x640 1 arco_superior, 119.5ms
# Speed: 6.4ms preprocess, 119.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0129.jpeg
# 📂 Copiada a 'arco_superior': image0129.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0130.jpeg: 640x640 1 arco_superior, 107.0ms
# Speed: 5.2ms preprocess, 107.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0130.jpeg
# 📂 Copiada a 'arco_superior': image0130.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0131.jpeg: 640x640 1 arco_superior, 101.1ms
# Speed: 6.4ms preprocess, 101.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0131.jpeg
# 📂 Copiada a 'arco_superior': image0131.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0132.jpeg: 640x640 1 arco_superior, 90.8ms
# Speed: 5.6ms preprocess, 90.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0132.jpeg
# 📂 Copiada a 'arco_superior': image0132.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0133.jpeg: 640x640 1 arco_superior, 96.0ms
# Speed: 6.8ms preprocess, 96.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0133.jpeg
# 📂 Copiada a 'arco_superior': image0133.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0134.jpeg: 640x640 1 arco_superior, 115.4ms
# Speed: 4.6ms preprocess, 115.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0134.jpeg
# 📂 Copiada a 'arco_superior': image0134.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0135.jpeg: 640x640 1 arco_superior, 89.4ms
# Speed: 6.4ms preprocess, 89.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0135.jpeg
# 📂 Copiada a 'arco_superior': image0135.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0136.jpeg: 640x640 1 arco_superior, 109.1ms
# Speed: 3.7ms preprocess, 109.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0136.jpeg
# 📂 Copiada a 'arco_superior': image0136.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0137.jpeg: 640x640 1 arco_superior, 88.4ms
# Speed: 5.7ms preprocess, 88.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0137.jpeg
# 📂 Copiada a 'arco_superior': image0137.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0138.jpeg: 640x640 1 arco_superior, 82.0ms
# Speed: 5.5ms preprocess, 82.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0138.jpeg
# 📂 Copiada a 'arco_superior': image0138.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0139.jpeg: 640x640 1 arco_superior, 100.4ms
# Speed: 4.6ms preprocess, 100.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0139.jpeg
# 📂 Copiada a 'arco_superior': image0139.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0140.jpeg: 640x640 1 arco_superior, 108.6ms
# Speed: 5.5ms preprocess, 108.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0140.jpeg
# 📂 Copiada a 'arco_superior': image0140.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0141.jpeg: 640x640 1 arco_superior, 93.2ms
# Speed: 5.5ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0141.jpeg
# 📂 Copiada a 'arco_superior': image0141.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0142.jpeg: 640x640 1 arco_superior, 92.6ms
# Speed: 6.7ms preprocess, 92.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0142.jpeg
# 📂 Copiada a 'arco_superior': image0142.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0143.jpeg: 640x640 1 arco_superior, 94.2ms
# Speed: 3.4ms preprocess, 94.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0143.jpeg
# 📂 Copiada a 'arco_superior': image0143.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0144.jpeg: 640x640 1 arco_superior, 100.8ms
# Speed: 6.6ms preprocess, 100.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0144.jpeg
# 📂 Copiada a 'arco_superior': image0144.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0145.jpeg: 640x640 1 arco_superior, 123.3ms
# Speed: 9.8ms preprocess, 123.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0145.jpeg
# 📂 Copiada a 'arco_superior': image0145.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0146.jpeg: 640x640 1 arco_superior, 90.5ms
# Speed: 5.8ms preprocess, 90.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0146.jpeg
# 📂 Copiada a 'arco_superior': image0146.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0147.jpeg: 640x640 1 arco_superior, 146.6ms
# Speed: 8.6ms preprocess, 146.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0147.jpeg
# 📂 Copiada a 'arco_superior': image0147.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0148.jpeg: 640x640 1 arco_superior, 99.9ms
# Speed: 6.0ms preprocess, 99.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0148.jpeg
# 📂 Copiada a 'arco_superior': image0148.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0149.jpeg: 640x640 1 arco_superior, 99.1ms
# Speed: 7.6ms preprocess, 99.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0149.jpeg
# 📂 Copiada a 'arco_superior': image0149.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0150.jpeg: 640x640 1 arco_superior, 107.0ms
# ...
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0355.jpeg: 640x640 (no detections), 115.3ms
# Speed: 5.3ms preprocess, 115.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0355.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0356.jpeg: 640x640 (no detections), 119.5ms
# Speed: 5.5ms preprocess, 119.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0356.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0357.jpeg: 640x640 (no detections), 109.1ms
# Speed: 6.1ms preprocess, 109.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0357.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0358.jpeg: 640x640 (no detections), 104.1ms
# Speed: 5.1ms preprocess, 104.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0358.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0359.jpeg: 640x640 (no detections), 103.2ms
# Speed: 5.0ms preprocess, 103.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0359.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0360.jpeg: 640x640 (no detections), 92.2ms
# Speed: 5.2ms preprocess, 92.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0360.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0361.jpeg: 640x640 (no detections), 114.2ms
# Speed: 5.4ms preprocess, 114.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0361.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0362.jpeg: 640x640 (no detections), 113.2ms
# Speed: 4.9ms preprocess, 113.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0362.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0363.jpeg: 640x640 (no detections), 158.1ms
# Speed: 6.4ms preprocess, 158.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0363.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0364.jpeg: 640x640 (no detections), 108.6ms
# Speed: 6.4ms preprocess, 108.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0364.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0365.jpeg: 640x640 (no detections), 108.6ms
# Speed: 5.0ms preprocess, 108.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0365.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0366.jpeg: 640x640 (no detections), 111.8ms
# Speed: 5.2ms preprocess, 111.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0366.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0367.jpeg: 640x640 (no detections), 105.8ms
# Speed: 5.7ms preprocess, 105.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0367.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0368.jpeg: 640x640 (no detections), 104.6ms
# Speed: 6.1ms preprocess, 104.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0368.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0369.jpeg: 640x640 (no detections), 114.4ms
# Speed: 5.5ms preprocess, 114.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0369.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0370.jpeg: 640x640 (no detections), 106.2ms
# Speed: 5.8ms preprocess, 106.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0370.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0371.jpeg: 640x640 (no detections), 113.2ms
# Speed: 4.7ms preprocess, 113.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0371.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0372.jpeg: 640x640 (no detections), 105.8ms
# Speed: 9.5ms preprocess, 105.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0372.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0373.jpeg: 640x640 (no detections), 98.5ms
# Speed: 4.9ms preprocess, 98.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0373.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0374.jpeg: 640x640 (no detections), 99.1ms
# Speed: 6.2ms preprocess, 99.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0374.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0375.jpeg: 640x640 (no detections), 107.3ms
# Speed: 4.7ms preprocess, 107.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0375.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0376.jpeg: 640x640 (no detections), 118.3ms
# Speed: 7.7ms preprocess, 118.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0376.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0377.jpeg: 640x640 (no detections), 117.7ms
# Speed: 3.4ms preprocess, 117.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0377.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0378.jpeg: 640x640 (no detections), 112.5ms
# Speed: 7.1ms preprocess, 112.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0378.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0379.jpeg: 640x640 (no detections), 120.6ms
# Speed: 5.6ms preprocess, 120.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0379.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0380.jpeg: 640x640 (no detections), 99.5ms
# Speed: 5.3ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0380.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0381.jpeg: 640x640 (no detections), 95.1ms
# Speed: 6.3ms preprocess, 95.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0381.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0382.jpeg: 640x640 (no detections), 99.8ms
# Speed: 4.7ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0382.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0383.jpeg: 640x640 (no detections), 96.9ms
# Speed: 4.6ms preprocess, 96.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0383.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0384.jpeg: 640x640 (no detections), 109.0ms
# Speed: 4.8ms preprocess, 109.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0384.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0385.jpeg: 640x640 (no detections), 100.8ms
# Speed: 4.8ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0385.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0386.jpeg: 640x640 (no detections), 96.7ms
# Speed: 4.6ms preprocess, 96.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0386.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0387.jpeg: 640x640 (no detections), 140.2ms
# Speed: 6.4ms preprocess, 140.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0387.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0388.jpeg: 640x640 (no detections), 113.3ms
# Speed: 5.1ms preprocess, 113.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0388.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0389.jpeg: 640x640 (no detections), 110.9ms
# Speed: 5.8ms preprocess, 110.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0389.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0390.jpeg: 640x640 (no detections), 105.4ms
# Speed: 4.8ms preprocess, 105.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0390.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0391.jpeg: 640x640 (no detections), 110.2ms
# Speed: 5.6ms preprocess, 110.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0391.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0392.jpeg: 640x640 (no detections), 101.3ms
# Speed: 5.3ms preprocess, 101.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0392.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0393.jpeg: 640x640 (no detections), 107.5ms
# Speed: 7.3ms preprocess, 107.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0393.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0394.jpeg: 640x640 (no detections), 99.4ms
# Speed: 7.4ms preprocess, 99.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0394.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0395.jpeg: 640x640 (no detections), 101.2ms
# Speed: 5.0ms preprocess, 101.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0395.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0396.jpeg: 640x640 (no detections), 97.6ms
# Speed: 7.0ms preprocess, 97.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0396.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0397.jpeg: 640x640 (no detections), 110.1ms
# Speed: 4.7ms preprocess, 110.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0397.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0398.jpeg: 640x640 (no detections), 112.0ms
# Speed: 5.0ms preprocess, 112.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0398.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0399.jpeg: 640x640 (no detections), 123.3ms
# Speed: 5.5ms preprocess, 123.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0399.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0400.jpeg: 640x640 (no detections), 118.1ms
# Speed: 5.4ms preprocess, 118.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0400.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0401.jpeg: 640x640 (no detections), 98.6ms
# Speed: 7.0ms preprocess, 98.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0401.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0402.jpeg: 640x640 (no detections), 94.5ms
# Speed: 5.0ms preprocess, 94.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0402.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0403.jpeg: 640x640 (no detections), 97.2ms
# Speed: 4.9ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0403.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0404.jpeg: 640x640 (no detections), 99.8ms
# Speed: 4.6ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0404.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0405.jpeg: 640x640 (no detections), 105.2ms
# Speed: 5.4ms preprocess, 105.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/detections/image0405.jpeg
# 🚀 Detección completada. Las imágenes procesadas están en 'output/', y las de arco superior en 'output/arco_superior/'.
