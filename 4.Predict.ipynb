# %%
import os
import cv2
import shutil
from ultralytics import YOLO

# === RUTAS ===
# Primer modelo: detectar arco superior
model_path_1 = "C:/Users/ana.torres/DetectarArcoSuperior/runs/detect/train/weights/best.pt"
# Segundo modelo: detectar dientes del arco superior
model_path_2 = "C:/Users/ana.torres/BioMod/DetectarDientes/runs/detect/train10/weights/best.pt"

input_folder = "C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/"
output_folder = os.path.join(input_folder, "detections")
arco_superior_folder = os.path.join(output_folder, "arco_superior")
labels_folder_1 = os.path.join(output_folder, "labels_arco")
teeth_detection_folder = os.path.join(output_folder, "deteccion_dientes")
labels_folder_2 = os.path.join(output_folder, "labels_dientes")

# === CREAR CARPETAS DE SALIDA ===
os.makedirs(output_folder, exist_ok=True)
os.makedirs(arco_superior_folder, exist_ok=True)
os.makedirs(labels_folder_1, exist_ok=True)
os.makedirs(teeth_detection_folder, exist_ok=True)
os.makedirs(labels_folder_2, exist_ok=True)

# === CARGAR MODELOS ===
model_arco = YOLO(model_path_1)
model_dientes = YOLO(model_path_2)

# === LISTA DE IMÁGENES ===
image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

# === PROCESO FASE 1: DETECCIÓN DE ARCO SUPERIOR ===
for image_name in image_files:
    image_path = os.path.join(input_folder, image_name)
    results = model_arco(image_path)

    img = cv2.imread(image_path)
    height, width = img.shape[:2]
    save_in_arco_superior = False
    contains_arco_inferior = False
    yolo_annotations = []

    for result in results:
        boxes = result.boxes.xyxy
        confidences = result.boxes.conf
        class_ids = result.boxes.cls.int().tolist()

        for i, (box, conf, class_id) in enumerate(zip(boxes, confidences, class_ids)):
            x1, y1, x2, y2 = map(int, box)
            label = "Arco Superior" if class_id == 0 else "Arco Inferior"
            color = (0, 0, 255) if class_id == 0 else (255, 0, 0)

            cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
            cv2.putText(img, f"{label} ({conf:.2f})", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            # Formato YOLO normalizado
            x_center = ((x1 + x2) / 2) / width
            y_center = ((y1 + y2) / 2) / height
            box_width = (x2 - x1) / width
            box_height = (y2 - y1) / height

            yolo_annotations.append(f"{class_id} {x_center:.6f} {y_center:.6f} {box_width:.6f} {box_height:.6f}")

            if class_id == 0:
                save_in_arco_superior = True
            elif class_id == 1:
                contains_arco_inferior = True

    if save_in_arco_superior and not contains_arco_inferior:
        output_path = os.path.join(arco_superior_folder, image_name)
        cv2.imwrite(output_path, img)

        txt_filename = os.path.splitext(image_name)[0] + ".txt"
        txt_path = os.path.join(labels_folder_1, txt_filename)
        with open(txt_path, 'w') as f:
            f.write("\n".join(yolo_annotations))

        print(f"✅ Guardado (Arco): {output_path}")
        print(f"📄 Etiquetas arco: {txt_path}")
    else:
        print(f"❌ No guardada (Arco Inferior detectado o ambas clases presentes): {image_name}")

# === PROCESO FASE 2: DETECCIÓN DE DIENTES EN IMÁGENES FILTRADAS ===
arco_images = [f for f in os.listdir(arco_superior_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

for image_name in arco_images:
    image_path = os.path.join(arco_superior_folder, image_name)
    results = model_dientes(image_path)

    img = cv2.imread(image_path)
    height, width = img.shape[:2]
    yolo_teeth_annotations = []

    for result in results:
        boxes = result.boxes.xyxy
        confidences = result.boxes.conf
        class_ids = result.boxes.cls.int().tolist()

        for i, (box, conf, class_id) in enumerate(zip(boxes, confidences, class_ids)):
            x1, y1, x2, y2 = map(int, box)
            label = f"Diente {class_id}"
            color = (0, 255, 0)

            cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
            cv2.putText(img, f"{label} ({conf:.2f})", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            # YOLO formato
            x_center = ((x1 + x2) / 2) / width
            y_center = ((y1 + y2) / 2) / height
            box_width = (x2 - x1) / width
            box_height = (y2 - y1) / height

            yolo_teeth_annotations.append(f"{class_id} {x_center:.6f} {y_center:.6f} {box_width:.6f} {box_height:.6f}")

    output_teeth_path = os.path.join(teeth_detection_folder, image_name)
    cv2.imwrite(output_teeth_path, img)

    txt_filename = os.path.splitext(image_name)[0] + ".txt"
    txt_path = os.path.join(labels_folder_2, txt_filename)
    with open(txt_path, 'w') as f:
        f.write("\n".join(yolo_teeth_annotations))

    print(f"🦷 Guardado (Dientes): {output_teeth_path}")
    print(f"📄 Etiquetas dientes: {txt_path}")

print("\n🚀 Procesamiento COMPLETO.")
# Out:
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0001.jpeg: 640x640 (no detections), 170.6ms
# Speed: 5.7ms preprocess, 170.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0001.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0002.jpeg: 640x640 (no detections), 129.1ms
# Speed: 5.2ms preprocess, 129.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0002.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0003.jpeg: 640x640 (no detections), 179.6ms
# Speed: 5.2ms preprocess, 179.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0003.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0004.jpeg: 640x640 (no detections), 214.1ms
# Speed: 6.4ms preprocess, 214.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0004.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0005.jpeg: 640x640 (no detections), 230.6ms
# Speed: 7.6ms preprocess, 230.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0005.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0006.jpeg: 640x640 (no detections), 137.3ms
# Speed: 5.7ms preprocess, 137.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0006.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0007.jpeg: 640x640 (no detections), 173.1ms
# Speed: 4.7ms preprocess, 173.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0007.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0008.jpeg: 640x640 (no detections), 181.2ms
# Speed: 6.2ms preprocess, 181.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0008.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0009.jpeg: 640x640 (no detections), 112.2ms
# Speed: 5.4ms preprocess, 112.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0009.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0010.jpeg: 640x640 (no detections), 161.6ms
# Speed: 5.8ms preprocess, 161.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0010.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0011.jpeg: 640x640 (no detections), 165.5ms
# Speed: 5.0ms preprocess, 165.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0011.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0012.jpeg: 640x640 (no detections), 162.8ms
# Speed: 5.7ms preprocess, 162.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0012.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0013.jpeg: 640x640 (no detections), 159.1ms
# Speed: 6.8ms preprocess, 159.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0013.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0014.jpeg: 640x640 (no detections), 178.3ms
# Speed: 4.6ms preprocess, 178.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0014.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0015.jpeg: 640x640 (no detections), 169.3ms
# Speed: 6.9ms preprocess, 169.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0015.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0016.jpeg: 640x640 (no detections), 168.1ms
# Speed: 5.1ms preprocess, 168.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0016.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0017.jpeg: 640x640 (no detections), 179.0ms
# Speed: 5.0ms preprocess, 179.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0017.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0018.jpeg: 640x640 (no detections), 157.3ms
# Speed: 6.7ms preprocess, 157.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0018.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0019.jpeg: 640x640 (no detections), 148.4ms
# Speed: 5.2ms preprocess, 148.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0019.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0020.jpeg: 640x640 (no detections), 166.6ms
# Speed: 4.8ms preprocess, 166.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0020.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image
jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0114.jpeg: 640x640 1 arco_inferior, 155.0ms
# Speed: 5.8ms preprocess, 155.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0114.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0115.jpeg: 640x640 1 arco_superior, 1 arco_inferior, 131.4ms
# Speed: 9.0ms preprocess, 131.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0115.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0116.jpeg: 640x640 1 arco_superior, 1 arco_inferior, 148.7ms
# Speed: 5.3ms preprocess, 148.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0116.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0117.jpeg: 640x640 1 arco_superior, 1 arco_inferior, 148.5ms
# Speed: 5.4ms preprocess, 148.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0117.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0118.jpeg: 640x640 1 arco_superior, 1 arco_inferior, 125.9ms
# Speed: 5.0ms preprocess, 125.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ❌ No guardada (Arco Inferior detectado o ambas clases presentes): image0118.jpeg
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0119.jpeg: 640x640 1 arco_superior, 157.2ms
# Speed: 5.6ms preprocess, 157.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0119.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0119.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0120.jpeg: 640x640 1 arco_superior, 161.9ms
# Speed: 9.8ms preprocess, 161.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0120.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0120.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0121.jpeg: 640x640 1 arco_superior, 116.9ms
# Speed: 7.4ms preprocess, 116.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0121.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0121.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0122.jpeg: 640x640 1 arco_superior, 173.1ms
# Speed: 8.1ms preprocess, 173.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0122.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0122.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0123.jpeg: 640x640 1 arco_superior, 175.9ms
# Speed: 9.8ms preprocess, 175.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0123.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0123.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0124.jpeg: 640x640 1 arco_superior, 116.1ms
# Speed: 5.8ms preprocess, 116.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0124.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0124.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0125.jpeg: 640x640 1 arco_superior, 150.1ms
# Speed: 7.4ms preprocess, 150.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0125.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0125.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0126.jpeg: 640x640 1 arco_superior, 120.2ms
# Speed: 5.5ms preprocess, 120.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0126.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0126.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0127.jpeg: 640x640 1 arco_superior, 111.9ms
# Speed: 5.8ms preprocess, 111.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0127.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0127.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0128.jpeg: 640x640 1 arco_superior, 129.6ms
# Speed: 5.3ms preprocess, 129.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0128.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0128.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0129.jpeg: 640x640 1 arco_superior, 131.9ms
# Speed: 10.7ms preprocess, 131.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0129.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0129.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0130.jpeg: 640x640 1 arco_superior, 119.0ms
# Speed: 6.6ms preprocess, 119.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0130.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0130.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0131.jpeg: 640x640 1 arco_superior, 112.5ms
# Speed: 5.0ms preprocess, 112.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0131.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0131.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0132.jpeg: 640x640 1 arco_superior, 118.4ms
# Speed: 6.4ms preprocess, 118.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0132.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0132.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0133.jpeg: 640x640 1 arco_superior, 115.3ms
# Speed: 5.3ms preprocess, 115.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0133.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0133.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0134.jpeg: 640x640 1 arco_superior, 116.0ms
# Speed: 5.5ms preprocess, 116.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0134.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0134.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0135.jpeg: 640x640 1 arco_superior, 137.4ms
# Speed: 5.5ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0135.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0135.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0136.jpeg: 640x640 1 arco_superior, 118.3ms
# Speed: 6.8ms preprocess, 118.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0136.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0136.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0137.jpeg: 640x640 1 arco_superior, 121.8ms
# Speed: 5.8ms preprocess, 121.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0137.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0137.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0138.jpeg: 640x640 1 arco_superior, 148.6ms
# Speed: 6.9ms preprocess, 148.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0138.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0138.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0139.jpeg: 640x640 1 arco_superior, 146.2ms
# Speed: 5.7ms preprocess, 146.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0139.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0139.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0140.jpeg: 640x640 1 arco_superior, 113.4ms
# Speed: 6.7ms preprocess, 113.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0140.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0140.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0141.jpeg: 640x640 1 arco_superior, 120.7ms
# Speed: 6.0ms preprocess, 120.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0141.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0141.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0142.jpeg: 640x640 1 arco_superior, 112.6ms
# Speed: 6.1ms preprocess, 112.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0142.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0142.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0143.jpeg: 640x640 1 arco_superior, 142.4ms
# Speed: 5.5ms preprocess, 142.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0143.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0143.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0144.jpeg: 640x640 1 arco_superior, 112.5ms
# Speed: 5.9ms preprocess, 112.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0144.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0144.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0145.jpeg: 640x640 1 arco_superior, 108.6ms
# Speed: 3.1ms preprocess, 108.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0145.jpeg
# 📄 Etiquetas arco: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_arco\image0145.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\image0146.jpeg: 640x640 1 arco_superior, 105.0ms
# Speed: 6.2ms preprocess, 105.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ✅ Guardado (Arco): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\arco_superior\image0146.jpeg
# ...
# Speed: 6.1ms preprocess, 116.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0163.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0163.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0164.jpeg: 640x640 1 26, 109.6ms
# Speed: 6.0ms preprocess, 109.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0164.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0164.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0165.jpeg: 640x640 1 26, 127.9ms
# Speed: 6.4ms preprocess, 127.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0165.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0165.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0166.jpeg: 640x640 1 26, 109.0ms
# Speed: 9.5ms preprocess, 109.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0166.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0166.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0167.jpeg: 640x640 1 26, 113.4ms
# Speed: 5.3ms preprocess, 113.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0167.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0167.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0168.jpeg: 640x640 1 26, 105.0ms
# Speed: 4.3ms preprocess, 105.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0168.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0168.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0169.jpeg: 640x640 (no detections), 112.5ms
# Speed: 6.4ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0169.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0169.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0170.jpeg: 640x640 (no detections), 110.1ms
# Speed: 7.1ms preprocess, 110.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0170.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0170.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0171.jpeg: 640x640 (no detections), 116.9ms
# Speed: 4.6ms preprocess, 116.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0171.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0171.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0172.jpeg: 640x640 (no detections), 110.3ms
# Speed: 5.8ms preprocess, 110.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0172.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0172.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0173.jpeg: 640x640 (no detections), 117.7ms
# Speed: 5.5ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0173.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0173.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0174.jpeg: 640x640 (no detections), 104.3ms
# Speed: 6.1ms preprocess, 104.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0174.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0174.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0175.jpeg: 640x640 (no detections), 125.6ms
# Speed: 6.5ms preprocess, 125.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0175.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0175.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0176.jpeg: 640x640 (no detections), 133.2ms
# Speed: 4.6ms preprocess, 133.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0176.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0176.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0177.jpeg: 640x640 (no detections), 117.5ms
# Speed: 7.1ms preprocess, 117.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0177.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0177.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0178.jpeg: 640x640 (no detections), 118.1ms
# Speed: 6.2ms preprocess, 118.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0178.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0178.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0179.jpeg: 640x640 (no detections), 115.6ms
# Speed: 6.0ms preprocess, 115.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0179.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0179.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0180.jpeg: 640x640 (no detections), 122.6ms
# Speed: 5.9ms preprocess, 122.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0180.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0180.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0181.jpeg: 640x640 (no detections), 105.4ms
# Speed: 4.5ms preprocess, 105.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0181.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0181.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0182.jpeg: 640x640 (no detections), 105.5ms
# Speed: 6.6ms preprocess, 105.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0182.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0182.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0183.jpeg: 640x640 (no detections), 132.8ms
# Speed: 4.0ms preprocess, 132.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0183.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0183.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0184.jpeg: 640x640 (no detections), 121.7ms
# Speed: 4.4ms preprocess, 121.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0184.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0184.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0185.jpeg: 640x640 (no detections), 127.1ms
# Speed: 7.5ms preprocess, 127.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0185.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0185.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0186.jpeg: 640x640 (no detections), 120.8ms
# Speed: 5.3ms preprocess, 120.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0186.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0186.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0187.jpeg: 640x640 (no detections), 128.3ms
# Speed: 6.0ms preprocess, 128.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0187.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0187.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0188.jpeg: 640x640 (no detections), 123.5ms
# Speed: 4.2ms preprocess, 123.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0188.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0188.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0189.jpeg: 640x640 (no detections), 107.3ms
# Speed: 5.0ms preprocess, 107.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0189.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0189.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0190.jpeg: 640x640 (no detections), 114.4ms
# Speed: 5.5ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0190.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0190.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0191.jpeg: 640x640 (no detections), 119.5ms
# Speed: 7.6ms preprocess, 119.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0191.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0191.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0192.jpeg: 640x640 (no detections), 114.7ms
# Speed: 3.7ms preprocess, 114.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0192.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0192.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0193.jpeg: 640x640 (no detections), 120.6ms
# Speed: 4.6ms preprocess, 120.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0193.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0193.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0194.jpeg: 640x640 (no detections), 117.4ms
# Speed: 5.6ms preprocess, 117.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0194.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0194.txt
#
# image 1/1 C:\Users\ana.torres\Desktop\python\biomod\DICOM\caso19\jpeg\detections\arco_superior\image0197.jpeg: 640x640 (no detections), 114.7ms
# Speed: 4.0ms preprocess, 114.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# 🦷 Guardado (Dientes): C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\deteccion_dientes\image0197.jpeg
# 📄 Etiquetas dientes: C:/Users/ana.torres/Desktop/python/biomod/DICOM/caso19/jpeg/detections\labels_dientes\image0197.txt
#
# 🚀 Procesamiento COMPLETO.
